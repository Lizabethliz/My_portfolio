# %% [markdown]
# ### MERGING DATAFRAMES

# %%
import pandas as pd

# %%
outlet_small = pd.read_csv('outlet_size_small.csv')
outlet_medium = pd.read_csv('outlet_size_medium.csv')
oulet_high = pd.read_csv('outlet_size_high.csv')

# %%
outlet_small
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA03        18.50          Regular         0.045464
# 1              FDS46        17.60          Regular         0.047257
# 2              FDP49         9.00          Regular         0.069089
# 3              FDU02        13.35          Low Fat         0.102492
# 4              NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 2383           FDN58        13.80          Regular         0.056862
# 2384           FDH31        12.00          Regular         0.020407
# 2385           FDF53        20.75              reg         0.083607
# 2386           NCJ29        10.60          Low Fat         0.035186
# 2387           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                  Dairy  144.1102            OUT046  Supermarket Type1
# ...

# %%
outlet_medium
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDP36       10.395          Regular         0.000000
# 4              FDP10          NaN          Low Fat         0.127470
# ...              ...          ...              ...              ...
# 2788           DRF37       17.250          Low Fat         0.084676
# 2789           FDF05       17.500          Low Fat         0.026980
# 2790           FDH24       20.700          Low Fat         0.021518
# 2791           NCJ19       18.600          Low Fat         0.118661
# 2792           FDN46        7.210          Regular         0.145221
#
#          Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0            Dairy  249.8092            OUT049  Supermarket Type1
# ...

# %%
oulet_high
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             NCD19        8.930          Low Fat         0.000000
# 1             FDO10       13.650          Regular         0.012741
# 2             FDF32       16.350          Low Fat         0.068024
# 3             FDN22       18.850          Regular         0.138190
# 4             DRJ59       11.650          low fat         0.019356
# ..              ...          ...              ...              ...
# 927           FDQ31        5.785          Regular         0.053802
# 928           FDJ32       10.695          Low Fat         0.057744
# 929           DRJ49        6.865          Low Fat         0.000000
# 930           FDR26       20.700          Low Fat         0.042801
# 931           FDF22        6.865          Low Fat         0.056783
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                Household   53.8614            OUT013  Supermarket Type1
# ...

# %% [markdown]
# ### CONCAT() METHOD

# %%
#Axis = 0 means join by row
#Axis = 1 means join by column
outlet_full = pd.concat([outlet_small, outlet_medium, oulet_high], axis = 0)

# %%
outlet_full
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0             FDA03       18.500          Regular         0.045464
# 1             FDS46       17.600          Regular         0.047257
# 2             FDP49        9.000          Regular         0.069089
# 3             FDU02       13.350          Low Fat         0.102492
# 4             NCB30       14.600          Low Fat         0.025698
# ..              ...          ...              ...              ...
# 927           FDQ31        5.785          Regular         0.053802
# 928           FDJ32       10.695          Low Fat         0.057744
# 929           DRJ49        6.865          Low Fat         0.000000
# 930           FDR26       20.700          Low Fat         0.042801
# 931           FDF22        6.865          Low Fat         0.056783
#
#                  Item_Type  Item_MRP Outlet_Identifier        Outlet_Type  \
# 0                    Dairy  144.1102            OUT046  Supermarket Type1
# ...

# %%
print(outlet_small.shape)
print(outlet_medium.shape)
print(oulet_high.shape)
print(outlet_full.shape)
# Out:
# (2388, 9)
# (2793, 9)
# (932, 9)
# (6113, 9)

# %%
item_identifier = pd.read_csv('item_idenifier.csv')

# %%
item_identifier
# Out:
#    Item_Identifier
# 0            DRI51
# 1            FDL48
# 2            FDL38
# 3            FDF17
# 4            FDN56
# ..             ...
# 95           FDQ59
# 96           FDQ01
# 97           FDD57
# 98           FDG41
# 99           NCM42
#
# [100 rows x 1 columns]

# %%
item_identifier.shape
# Out:
# (100, 1)

# %%
data1 = {
  "name": ["Sally", "Mary", "John"],
  "age": [50, 40, 30]
}

data2 = {
  "name": ["Sally", "Petef", "Micky"],
  "age": [77, 44, 22]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

# %%
df1
# Out:
#     name  age
# 0  Sally   50
# 1   Mary   40
# 2   John   30

# %%
df2
# Out:
#     name  age
# 0  Sally   77
# 1  Petef   44
# 2  Micky   22

# %% [markdown]
# ## TYPES OF JOIN

# %% [markdown]
# ### RIGHT JOIN

# %%
df1.merge(df2, how = "right", on = "name")
# Out:
#     name  age_x  age_y
# 0  Sally   50.0     77
# 1  Petef    NaN     44
# 2  Micky    NaN     22

# %% [markdown]
# ### INNER JOIN

# %%
df1.merge(df2, how = "inner", on = "name")
# Out:
#     name  age_x  age_y
# 0  Sally     50     77

# %% [markdown]
# ### OUTER JOIN

# %%
df1.merge(df2, how = "outer", on = "name")
# Out:
#     name  age_x  age_y
# 0   John   30.0    NaN
# 1   Mary   40.0    NaN
# 2  Micky    NaN   22.0
# 3  Petef    NaN   44.0
# 4  Sally   50.0   77.0

# %% [markdown]
# ### OUTER JOIN

# %%
df1.merge(df2, how = "right", on = "name")
