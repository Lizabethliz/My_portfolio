# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('master.csv')
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df = pd.read_csv('master.csv')

# %%
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df.drop(['HDI for year'], axis = 1, inplace = True)

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  gdp_for_year ($)   \
# 0                   6.71     Albania1987      2,156,624,900
# ...

# %%
df.isnull().sum()
# Out:
# country               0
# year                  0
# sex                   0
# age                   0
# suicides_no           0
# population            0
# suicides/100k pop     0
# country-year          0
#  gdp_for_year ($)     0
# gdp_per_capita ($)    0
# generation            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### QU 1 Suicide rate over the years based on sex? Draw a quantitative report from your analysis

# %%
sucide_rate_by_sex_year = df.groupby(['year', 'sex'], as_index=False)['suicides_no'].mean()

# %%
sucide_rate_by_sex_year
# Out:
#     year     sex  suicides_no
# 0   1985  female   112.774306
# 1   1985    male   290.222222
# 2   1986  female   117.541667
# 3   1986    male   301.451389
# 4   1987  female   108.043210
# ..   ...     ...          ...
# 59  2014    male   366.299145
# 60  2015  female   127.010753
# 61  2015    male   420.408602
# 62  2016  female    43.800000
# 63  2016    male   151.237500
#
# [64 rows x 3 columns]

# %%
sns.lineplot(data = sucide_rate_by_sex_year, x = 'year', y = 'suicides_no', hue = 'sex')
plt.title('sucide_rate_by_sex_year')
plt.show()

# %% [markdown]
# ### QU 2 Is age a considerable factor of committing suicide? Provide a report based on your analysis

# %%
sucide_rate_by_age = df.groupby(['age'], as_index=False)['suicides_no'].mean()

# %%
sucide_rate_by_age
# Out:
#            age  suicides_no
# 0  15-24 years   174.179664
# 1  25-34 years   242.118053
# 2  35-54 years   528.250969
# 3   5-14 years    11.337093
# 4  55-74 years   357.269065
# 5    75+ years   140.697544

# %%
sns.violinplot(data = df , x = 'suicides_no', y = 'age', palette='Set1')
plt.title('sucide_rate_by_age') 
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8852\1743228661.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data = df , x = 'suicides_no', y = 'age', palette='Set1')

# %% [markdown]
# ### QU 3 The highest suicide rate happened in which of the generations?

# %%
sucide_rate_by_generation = df.groupby(['generation'], as_index=False)['suicides_no'].mean()

# %%
sucide_rate_by_generation
# Out:
#         generation  suicides_no
# 0          Boomers   457.815230
# 1  G.I. Generation   185.863338
# 2     Generation X   239.201623
# 3     Generation Z    10.820408
# 4       Millenials   106.683607
# 5           Silent   279.972344

# %%
sns.barplot(data = sucide_rate_by_generation , x='suicides_no', y='generation', color = '#FF8E00')
plt.title('sucide_rate_by_generation')
plt.show()

# %% [markdown]
# ### QU 4 List the top 10 countries with the highest number of suicide rate?

# %%
sucide_rate_by_countries = df.groupby(['country'], as_index=False)['suicides_no'].mean()

# %%
sucide_rate_by_countries
# Out:
#                   country  suicides_no
# 0                 Albania     7.462121
# 1     Antigua and Barbuda     0.033951
# 2               Argentina   221.018817
# 3                 Armenia     6.392617
# 4                   Aruba     0.601190
# ..                    ...          ...
# 96   United Arab Emirates     8.638889
# 97         United Kingdom   367.755376
# 98          United States  2779.604839
# 99                Uruguay    39.101190
# 100            Uzbekistan   131.829545
#
# [101 rows x 2 columns]

# %%
sucide_rate_by_top_10_countries = sucide_rate_by_countries.sort_values(by = 'suicides_no', ascending=False).head(10)

# %%
sucide_rate_by_top_10_countries
# Out:
#                country  suicides_no
# 75  Russian Federation  3733.771605
# 98       United States  2779.604839
# 46               Japan  2169.091398
# 95             Ukraine   952.232143
# 35             Germany   933.532051
# 33              France   914.241667
# 73   Republic of Korea   703.575269
# 15              Brazil   609.174731
# 69              Poland   482.979167
# 87           Sri Lanka   421.522727

# %%
sns.barplot(data = sucide_rate_by_top_10_countries , x='suicides_no', y='country', color = '#FF8E00')
plt.title('sucide_rate_by_top_10_countries')
plt.show()

# %% [markdown]
# ### QU 5 Does the degree of national wealth(gdp_per_capital) a considerable factor to suicide rate?

# %%
suicide_rate_by_gdp_per_capita = df.groupby(['gdp_per_capita ($)'], as_index=False)['suicides_no'].mean()

# %%
suicide_rate_by_gdp_per_capita
# Out:
#       gdp_per_capita ($)  suicides_no
# 0                    251     3.916667
# 1                    291    46.333333
# 2                    313    42.500000
# 3                    345    46.666667
# 4                    357     8.833333
# ...                  ...          ...
# 2228              113120     4.250000
# 2229              120423     3.333333
# 2230              121315     3.583333
# 2231              122729     4.583333
# 2232              126352     5.583333
#
# [2233 rows x 2 columns]

# %%
suicide_rate_by_gdp_per_capita = suicide_rate_by_gdp_per_capita.sort_values(by = 'suicides_no', ascending=False).head(20)

# %%
suicide_rate_by_gdp_per_capita
# Out:
#      gdp_per_capita ($)  suicides_no
# 445                2853  5118.333333
# 443                2844  5045.666667
# 437                2813  4792.583333
# 201                1412  4747.833333
# 281                1879  4718.250000
# 488                3160  4653.833333
# 392                2527  4585.333333
# 451                2907  4562.166667
# 297                1948  4293.166667
# 663                4312  4091.333333

# %%
sns.scatterplot(data = suicide_rate_by_gdp_per_capita, x ='gdp_per_capita ($)', y  ='suicides_no' , color ='#FF8E00')
plt.title('suicide_rate_by_gdp_per_capita')
plt.show()

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  gdp_for_year ($)   \
# 0                   6.71     Albania1987      2,156,624,900
# ...
