# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('data.csv')
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df = pd.read_csv('data.csv')

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.drop(['condition', 'yr_built', 'yr_renovated', 'statezip', 'country', 'street', 'date'], axis = 1, inplace = True)

# %%
categorical_columns = df.select_dtypes(include=['object']).columns
categorical_columns
# Out:
# Index(['city'], dtype='object')

# %%
numerical_columns = df.select_dtypes(['int64', 'float64']).columns
numerical_columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
df.waterfront.unique()
# Out:
# array([0, 1])

# %%
for x in categorical_columns:
    print(df[x].unique())
# Out:
# ['Shoreline' 'Seattle' 'Kent' 'Bellevue' 'Redmond' 'Maple Valley'
#  'North Bend' 'Lake Forest Park' 'Sammamish' 'Auburn' 'Des Moines'
#  'Bothell' 'Federal Way' 'Kirkland' 'Issaquah' 'Woodinville'
#  'Normandy Park' 'Fall City' 'Renton' 'Carnation' 'Snoqualmie' 'Duvall'
#  'Burien' 'Covington' 'Inglewood-Finn Hill' 'Kenmore' 'Newcastle'
#  'Mercer Island' 'Black Diamond' 'Ravensdale' 'Clyde Hill' 'Algona'
#  'Skykomish' 'Tukwila' 'Vashon' 'Yarrow Point' 'SeaTac' 'Medina'
#  'Enumclaw' 'Snoqualmie Pass' 'Pacific' 'Beaux Arts Village' 'Preston'
#  'Milton']

# %% [markdown]
# ### Correlation between numerical variable/columns

# %%
df[numerical_columns].corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430410  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594884  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.761154  0.107837  0.486428
# sqft_living    0.430410  0.594884   0.761154     1.000000  0.210538  0.344850
# sqft_lot       0.050451  0.068819   0.107837     0.210538  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344850  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117616  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311009  0.073907  0.031211
# sqft_above     0.367570  0.484705   0.689918     0.876443  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.447206  0.034842 -0.255510
#
#                waterfront      view  sqft_above  sqft_basement
# ...

# %% [markdown]
# ### DATA ENCODING FOR CATEGORICAL COLUMNS
# ### LABEL ENCODING

# %%
categorical_columns
# Out:
# Index(['city'], dtype='object')

# %%
# from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
for x in categorical_columns:
    df[x] = label_enc.fit_transform(df[x])

# %%
df.head()
# Out:
#        price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0   313000.0       3.0       1.50         1340      7912     1.5           0
# 1  2384000.0       5.0       2.50         3650      9050     2.0           0
# 2   342000.0       3.0       2.00         1930     11947     1.0           0
# 3   420000.0       3.0       2.25         2000      8030     1.0           0
# 4   550000.0       4.0       2.50         1940     10500     1.0           0
#
#    view  sqft_above  sqft_basement  city
# 0     0        1340              0    36
# 1     4        3370            280    35
# 2     0        1930              0    18
# 3     0        1000           1000     3
# 4     0        1140            800    31

# %% [markdown]
# ### CREATING X(INPUT) AND Y(INPUT) FEATURES FOR ML MODEL

# %%
y = df.price
x = df.drop('price', axis = 1)

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       1.50         1340      7912     1.5           0     0
# 1       5.0       2.50         3650      9050     2.0           0     4
# 2       3.0       2.00         1930     11947     1.0           0     0
# 3       3.0       2.25         2000      8030     1.0           0     0
# 4       4.0       2.50         1940     10500     1.0           0     0
#
#    sqft_above  sqft_basement  city
# 0        1340              0    36
# 1        3370            280    35
# 2        1930              0    18
# 3        1000           1000     3
# 4        1140            800    31

# %%
y.head()
# Out:
# 0     313000.0
# 1    2384000.0
# 2     342000.0
# 3     420000.0
# 4     550000.0
# Name: price, dtype: float64

# %% [markdown]
# ### STANDARD X(INPUT) USING STANDARD SCALER
# #### SPLIT DATA INTO TRAINING SET AND TEST SET
# #### it will be splitted into 70%(train) and 30%(test)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state = 20)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (4600, 10)
# (3450, 10)
# (1150, 10)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4600,)
# (3450,)
# (1150,)

# %% [markdown]
# ## MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Initializing the model
LR = LinearRegression()

# %%
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## MODEL EVALUATION

# %%
predicted_values = LR.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# np.float64(74319963588.05046)

# %%
LR.predict([[3.0, 1.50,	1340, 7912,	1.5, 0,	0, 1340, 0, 36]])
# Out:
# C:\Users\HP\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([372610.86990845])

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05       3.0       1.50         1340      7912     1.5
# 1     2.384000e+06       5.0       2.50         3650      9050     2.0
# 2     3.420000e+05       3.0       2.00         1930     11947     1.0
# 3     4.200000e+05       3.0       2.25         2000      8030     1.0
# 4     5.500000e+05       4.0       2.50         1940     10500     1.0
# ...            ...       ...        ...          ...       ...     ...
# 4595  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599  2.206000e+05       3.0       2.50         1490      8102     2.0
#
#       waterfront  view  sqft_above  sqft_basement  city
# 0              0     0        1340              0    36
# ...

# %%
LR.intercept_
# Out:
# np.float64(49666.01903839741)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test, predicted_values)
plt.plot(y_test, y_test, c = "pink")
plt.show()

# %% [markdown]
# ### STANDARD X(INPUT) USING MINMAX SCALER

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       1.50         1340      7912     1.5           0     0
# 1       5.0       2.50         3650      9050     2.0           0     4
# 2       3.0       2.00         1930     11947     1.0           0     0
# 3       3.0       2.25         2000      8030     1.0           0     0
# 4       4.0       2.50         1940     10500     1.0           0     0
#
#    sqft_above  sqft_basement  city
# 0        1340              0    36
# 1        3370            280    35
# 2        1930              0    18
# 3        1000           1000     3
# 4        1140            800    31

# %%
# Scaling the price_in_rupees and carpet area because they are out of range
from sklearn.preprocessing import MinMaxScaler

# %%
# Initialize standard scalar
scaler = MinMaxScaler()

# %%
scaler.fit_transform(x[['sqft_living', 'sqft_lot', 'sqft_above']])
# Out:
# array([[0.07365224, 0.00677546, 0.10730088],
#        [0.24905087, 0.00783547, 0.33185841],
#        [0.11845103, 0.01053391, 0.17256637],
#        ...,
#        [0.20045558, 0.00593901, 0.2920354 ],
#        [0.13059985, 0.00558133, 0.07743363],
#        [0.08504176, 0.00695244, 0.12389381]])

# %%
x[['sqft_living', 'sqft_lot', 'sqft_above']] = scaler.fit_transform(x[['sqft_living', 'sqft_lot', 'sqft_above']])

# %%
x.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       3.0       1.50     0.073652  0.006775     1.5           0     0
# 1       5.0       2.50     0.249051  0.007835     2.0           0     4
# 2       3.0       2.00     0.118451  0.010534     1.0           0     0
# 3       3.0       2.25     0.123766  0.006885     1.0           0     0
# 4       4.0       2.50     0.119210  0.009186     1.0           0     0
#
#    sqft_above  sqft_basement  city
# 0    0.107301              0    36
# 1    0.331858            280    35
# 2    0.172566              0    18
# 3    0.069690           1000     3
# 4    0.085177            800    31

# %%
# Split x and y into train and test
x_train, x_test, y_train,y_test = train_test_split(x, y, random_state = 20)

# %%
# Initialize model
LR = LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_values = LR.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# np.float64(74319963588.04951)

# %% [markdown]
# ###  RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Initialize the regressor
rf = RandomForestRegressor(random_state = 40)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=40)

# %%
rf.predict(x_test)
# Out:
# array([ 842063.2625    ,  538954.79714286,  350287.02777778, ...,
#         573890.12      ,  244176.16      , 1398289.42      ])

# %%
predicted_values = rf.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# np.float64(113535526327.35504)

# %%
from sklearn.metrics import r2_score

# %%
y_pred_lr = LR.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print('Accuracy score of Linear regression is', r2_score(y_test, y_pred_lr))
print('Accuracy score of Random forest regression model is', r2_score(y_test, y_pred_rf))
# Out:
# Accuracy score of Linear regression is 0.5034904869733468
# Accuracy score of Random forest regression model is 0.24150300718010265

# %% [markdown]
# ### REGRESSION TASK
# #### it is when your label output(Y) is numerical
# #### N:B IT'S THE OUTPUT(Y) THAT DETERMINES IF THE TASK IS A REGRESSION OR CLASSIFICATION
